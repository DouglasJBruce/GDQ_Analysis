# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import datetime as dt

# %%
response = requests.get('https://www.speedrun.com/api/v1/users/gymnast86/personal-bests?embed=game,category')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'data': [{'place': 1,
#    'run': {'id': 'z5835njz',
#     'weblink': 'https://www.speedrun.com/tphd/run/z5835njz',
#     'game': 'm1zx70d0',
#     'level': None,
#     'category': 'vdo09m9d',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=OUIzcus1CfI'}]},
#     'comment': "Bad Arbiter's, City, and Zelda ",
#     'status': {'status': 'verified',
#      'examiner': 'y8dqky5j',
#      'verify-date': '2024-03-17T18:01:39Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2024-03-11',
#     'submitted': '2024-03-13T07:37:53Z',
#     'times': {'primary': 'PT5H1M41S',
#      'primary_t': 18101,
#      'realtime': 'PT5H1M41S',
#      'realtime_t': 18101,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gejn93d',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'onv7505n': '4lxz4w31'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/z5835njz'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gejn93d'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/y8dqky5j'}]},
#    'game': {'data': {'id': 'm1zx70d0',
#      'names': {'international': 'The Legend of Zelda: Twilight Princess HD',
#       'japanese': 'ゼルダの伝説 トワイライトプリンセス HD',
#       'twitch': 'The Legend of Zelda: Twilight Princess HD'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': 'tphd',
#      'weblink': 'https://www.speedrun.com/tphd',
#      'discord': 'https://discord.gg/tp',
#      'released': 2016,
#      'release-date': '2016-03-04',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'ingame'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gejn93d'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['9rnvvrnq'],
#      'engines': [],
#      'developers': ['xv6dvx62'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'e8e6m6j0': 'moderator',
#       '48g9l2xp': 'super-moderator',
#       'v8lkv2xm': 'moderator',
#       'e8eekq28': 'super-moderator',
#       'e8e2oy28': 'moderator',
#       'y8dqky5j': 'super-moderator'},
#      'created': '2016-02-04T01:17:53Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/logo?v=2761741'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/favicon?v=74ef72f'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/1st?v=76da8ac'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/2nd?v=040c939'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/3rd?v=9da1822'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/background?v=e6557d0'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=m1zx70d0'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zx70d0/category/ndxjx7v2'}]}},
#    'category': {'data': {'id': 'vdo09m9d',
#      'name': 'Glitchless',
#      'weblink': 'https://www.speedrun.com/tphd#Glitchless',
#      'type': 'per-game',
#      'rules': '#Banned Glitches\r\n* Any Out of bounds glitches / skips \r\n* Gate Clipping \r\n* Rupee / Midna Diving \r\n* Epona Slide \r\n* Sword & Shield Skip \r\n* Rocket Link \r\n* Moon Boots\r\n* Text Displacement\r\n* Using normal bombs in water \r\n* Long Jump Attack with Boomerang\r\n(enemy LJAs are allowed)\r\n* Keese LJAs\r\n* Super Jumps\r\n* Infinite Soup\r\n* Super Sliding\r\n* Early Gale Boomerang \r\n* Bombhouse Skip\r\n* Stealing the Bomb Bag \r\n* Pot Clip through Rock to Deku Toad \r\n* Floor Clipping \r\n* Opening Doors Backwards\r\n* Early City in the Sky (Statue clip) \r\n* Early Boss Key in CitS \r\n* Aeralfos Skip \r\n* Skipping Darknut Fight in Hyrule Castle',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=vdo09m9d'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zx70d0/category/vdo09m9d'}]}}},
#   {'place': 1,
#    'run': {'id': 'yldv32xm',
#     'weblink': 'https://www.speedrun.com/tphd/run/yldv32xm',
#     'game': 'm1zx70d0',
#     'level': None,
#     'category': 'vdo09m9d',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=OUIzcus1CfI'}]},
#     'comment': 'Slow start, but otherwise mostly good',
#     'status': {'status': 'verified',
#      'examiner': 'y8dqky5j',
#      'verify-date': '2024-03-15T14:43:48Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2024-03-11',
#     'submitted': '2024-03-13T07:46:25Z',
#     'times': {'primary': 'PT2H28M14S',
#      'primary_t': 8894,
#      'realtime': 'PT2H28M14S',
#      'realtime_t': 8894,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gejn93d',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'onv7505n': '814jdee1'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/yldv32xm'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gejn93d'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/y8dqky5j'}]},
#    'game': {'data': {'id': 'm1zx70d0',
#      'names': {'international': 'The Legend of Zelda: Twilight Princess HD',
#       'japanese': 'ゼルダの伝説 トワイライトプリンセス HD',
#       'twitch': 'The Legend of Zelda: Twilight Princess HD'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': 'tphd',
#      'weblink': 'https://www.speedrun.com/tphd',
#      'discord': 'https://discord.gg/tp',
#      'released': 2016,
#      'release-date': '2016-03-04',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'ingame'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gejn93d'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['9rnvvrnq'],
#      'engines': [],
#      'developers': ['xv6dvx62'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'e8e6m6j0': 'moderator',
#       '48g9l2xp': 'super-moderator',
#       'v8lkv2xm': 'moderator',
#       'e8eekq28': 'super-moderator',
#       'e8e2oy28': 'moderator',
#       'y8dqky5j': 'super-moderator'},
#      'created': '2016-02-04T01:17:53Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/logo?v=2761741'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/m1zx70d0/cover?v=3fe20c6'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/favicon?v=74ef72f'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/1st?v=76da8ac'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/2nd?v=040c939'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/3rd?v=9da1822'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/0w1y4ywn/background?v=e6557d0'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=m1zx70d0'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zx70d0/category/ndxjx7v2'}]}},
#    'category': {'data': {'id': 'vdo09m9d',
#      'name': 'Glitchless',
#      'weblink': 'https://www.speedrun.com/tphd#Glitchless',
#      'type': 'per-game',
#      'rules': '#Banned Glitches\r\n* Any Out of bounds glitches / skips \r\n* Gate Clipping \r\n* Rupee / Midna Diving \r\n* Epona Slide \r\n* Sword & Shield Skip \r\n* Rocket Link \r\n* Moon Boots\r\n* Text Displacement\r\n* Using normal bombs in water \r\n* Long Jump Attack with Boomerang\r\n(enemy LJAs are allowed)\r\n* Keese LJAs\r\n* Super Jumps\r\n* Infinite Soup\r\n* Super Sliding\r\n* Early Gale Boomerang \r\n* Bombhouse Skip\r\n* Stealing the Bomb Bag \r\n* Pot Clip through Rock to Deku Toad \r\n* Floor Clipping \r\n* Opening Doors Backwards\r\n* Early City in the Sky (Statue clip) \r\n* Early Boss Key in CitS \r\n* Aeralfos Skip \r\n* Skipping Darknut Fight in Hyrule Castle',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=vdo09m9d'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zx70d0/category/vdo09m9d'}]}}},
#   {'place': 1,
#    'run': {'id': 'mrvj338z',
#     'weblink': 'https://www.speedrun.com/totk/run/mrvj338z',
#     'game': 'v1px9276',
#     'level': None,
#     'category': 'wdmojz4k',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=J4d7rxCtErU'}]},
#     'comment': 'nice',
#     'status': {'status': 'verified',
#      'examiner': 'xko2erk8',
#      'verify-date': '2024-02-18T09:34:27Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2024-02-03',
#     'submitted': '2024-02-18T00:20:06Z',
#     'times': {'primary': 'PT2H39M17S',
#      'primary_t': 9557,
#      'realtime': 'PT2H39M17S',
#      'realtime_t': 9557,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '7m6ylw9p',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'jlz2gzyl': 'q65v56vl',
#      'p85p9dvl': 'qoxx2m5q',
#      'ql6wgzkn': 'qoxxdopq',
#      'e8mpe1v8': 'lr3z9zml'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/mrvj338z'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/7m6ylw9p'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/xko2erk8'}]},
#    'game': {'data': {'id': 'v1px9276',
#      'names': {'international': 'The Legend of Zelda: Tears of the Kingdom',
#       'japanese': None,
#       'twitch': 'The Legend of Zelda: Tears of the Kingdom'},
#      'boostReceived': 42,
#      'boostDistinctDonors': 8,
#      'abbreviation': 'totk',
#      'weblink': 'https://www.speedrun.com/totk',
#      'discord': 'https://discord.gg/ZT5TG2KQnx',
#      'released': 2023,
#      'release-date': '2023-05-12',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['7m6ylw9p'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['9rnvvrnq'],
#      'engines': [],
#      'developers': ['rzjvw1zl'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'qjopo7x6': 'super-moderator',
#       '48g9l2xp': 'super-moderator',
#       'y8dk1vgj': 'super-moderator',
#       'dx3lkkqx': 'super-moderator',
#       'v8ll6l28': 'super-moderator',
#       '0jm9drn8': 'super-moderator',
#       'j4rlnov8': 'moderator',
#       'j5wv5zqj': 'super-moderator',
#       'xko2erk8': 'super-moderator',
#       'x3w1yq2j': 'moderator'},
#      'created': '2023-04-23T09:49:08Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/logo?v=2b85778'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/favicon?v=5c5ccb8'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/1st?v=1510d39'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/2nd?v=9b28acb'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/3rd?v=fd63235'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/4th?v=ecb0db4'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/background?v=61ec174'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=v1px9276'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/w20mopzk'}]}},
#    'category': {'data': {'id': 'wdmojz4k',
#      'name': 'All Dungeons',
#      'weblink': 'https://www.speedrun.com/totk#All_Dungeons',
#      'type': 'per-game',
#      'rules': '* Runs must start from New Game or from a valid Intro Skip Save File in the Room of Awakening. Please see the Game Rules for more details.\r\n* For runs that start from New Game, timing starts from zero on hitting "start" in the main menu.\r\n* For runs that start from a valid Intro Skip Save File, timing starts from 6:40.867 on gaining control of Link in the Room of Awakening\r\n* Timing ends on touching Zelda\'s hand.\r\n* All temples must be beaten before beating Ganondorf.\r\n* All 5 vows must be collected before beating Ganondorf.\r\n* Phantom Ganon must be defeated in Hyrule Castle before beating Ganondorf.',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=wdmojz4k'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/wdmojz4k'}]}}},
#   {'place': 1,
#    'run': {'id': 'y6q1ld0z',
#     'weblink': 'https://www.speedrun.com/totk/run/y6q1ld0z',
#     'game': 'v1px9276',
#     'level': None,
#     'category': 'wdmojz4k',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=NcNCUK6aIq4'}]},
#     'comment': 'bad wind temple',
#     'status': {'status': 'verified',
#      'examiner': 'x3w1yq2j',
#      'verify-date': '2024-02-01T19:32:56Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2024-01-31',
#     'submitted': '2024-02-01T06:26:14Z',
#     'times': {'primary': 'PT2H40M20S',
#      'primary_t': 9620,
#      'realtime': 'PT2H40M20S',
#      'realtime_t': 9620,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '7m6ylw9p',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'jlz2gzyl': 'q65v56vl',
#      'p85p9dvl': 'qoxx2m5q',
#      'ql6wgzkn': 'qoxxdopq',
#      'e8mpe1v8': 'lr3z9zml'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/y6q1ld0z'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/7m6ylw9p'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/x3w1yq2j'}]},
#    'game': {'data': {'id': 'v1px9276',
#      'names': {'international': 'The Legend of Zelda: Tears of the Kingdom',
#       'japanese': None,
#       'twitch': 'The Legend of Zelda: Tears of the Kingdom'},
#      'boostReceived': 42,
#      'boostDistinctDonors': 8,
#      'abbreviation': 'totk',
#      'weblink': 'https://www.speedrun.com/totk',
#      'discord': 'https://discord.gg/ZT5TG2KQnx',
#      'released': 2023,
#      'release-date': '2023-05-12',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['7m6ylw9p'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['9rnvvrnq'],
#      'engines': [],
#      'developers': ['rzjvw1zl'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'qjopo7x6': 'super-moderator',
#       '48g9l2xp': 'super-moderator',
#       'y8dk1vgj': 'super-moderator',
#       'dx3lkkqx': 'super-moderator',
#       'v8ll6l28': 'super-moderator',
#       '0jm9drn8': 'super-moderator',
#       'j4rlnov8': 'moderator',
#       'j5wv5zqj': 'super-moderator',
#       'xko2erk8': 'super-moderator',
#       'x3w1yq2j': 'moderator'},
#      'created': '2023-04-23T09:49:08Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/logo?v=2b85778'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/favicon?v=5c5ccb8'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/1st?v=1510d39'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/2nd?v=9b28acb'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/3rd?v=fd63235'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/4th?v=ecb0db4'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/background?v=61ec174'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=v1px9276'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/w20mopzk'}]}},
#    'category': {'data': {'id': 'wdmojz4k',
#      'name': 'All Dungeons',
#      'weblink': 'https://www.speedrun.com/totk#All_Dungeons',
#      'type': 'per-game',
#      'rules': '* Runs must start from New Game or from a valid Intro Skip Save File in the Room of Awakening. Please see the Game Rules for more details.\r\n* For runs that start from New Game, timing starts from zero on hitting "start" in the main menu.\r\n* For runs that start from a valid Intro Skip Save File, timing starts from 6:40.867 on gaining control of Link in the Room of Awakening\r\n* Timing ends on touching Zelda\'s hand.\r\n* All temples must be beaten before beating Ganondorf.\r\n* All 5 vows must be collected before beating Ganondorf.\r\n* Phantom Ganon must be defeated in Hyrule Castle before beating Ganondorf.',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=wdmojz4k'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/wdmojz4k'}]}}},
#   {'place': 1,
#    'run': {'id': 'y4kg022m',
#     'weblink': 'https://www.speedrun.com/totk/run/y4kg022m',
#     'game': 'v1px9276',
#     'level': None,
#     'category': 'wdmojz4k',
#     'videos': {'links': [{'uri': 'https://youtu.be/cyXhoWTqIM0'}]},
#     'comment': 'Nice middle',
#     'status': {'status': 'verified',
#      'examiner': 'x3w1yq2j',
#      'verify-date': '2023-12-05T16:31:27Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2023-11-29',
#     'submitted': '2023-12-04T07:11:35Z',
#     'times': {'primary': 'PT2H42M30S',
#      'primary_t': 9750,
#      'realtime': 'PT2H42M30S',
#      'realtime_t': 9750,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '7m6ylw9p',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'jlz2gzyl': 'q65v56vl',
#      'p85p9dvl': 'qoxx2m5q',
#      'ql6wgzkn': 'qoxxdopq',
#      'e8mpe1v8': 'lr3z9zml'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/y4kg022m'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/7m6ylw9p'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/x3w1yq2j'}]},
#    'game': {'data': {'id': 'v1px9276',
#      'names': {'international': 'The Legend of Zelda: Tears of the Kingdom',
#       'japanese': None,
#       'twitch': 'The Legend of Zelda: Tears of the Kingdom'},
#      'boostReceived': 42,
#      'boostDistinctDonors': 8,
#      'abbreviation': 'totk',
#      'weblink': 'https://www.speedrun.com/totk',
#      'discord': 'https://discord.gg/ZT5TG2KQnx',
#      'released': 2023,
#      'release-date': '2023-05-12',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['7m6ylw9p'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['9rnvvrnq'],
#      'engines': [],
#      'developers': ['rzjvw1zl'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'qjopo7x6': 'super-moderator',
#       '48g9l2xp': 'super-moderator',
#       'y8dk1vgj': 'super-moderator',
#       'dx3lkkqx': 'super-moderator',
#       'v8ll6l28': 'super-moderator',
#       '0jm9drn8': 'super-moderator',
#       'j4rlnov8': 'moderator',
#       'j5wv5zqj': 'super-moderator',
#       'xko2erk8': 'super-moderator',
#       'x3w1yq2j': 'moderator'},
#      'created': '2023-04-23T09:49:08Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/logo?v=2b85778'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/favicon?v=5c5ccb8'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/1st?v=1510d39'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/2nd?v=9b28acb'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/3rd?v=fd63235'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/4th?v=ecb0db4'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/background?v=61ec174'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=v1px9276'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/w20mopzk'}]}},
#    'category': {'data': {'id': 'wdmojz4k',
#      'name': 'All Dungeons',
#      'weblink': 'https://www.speedrun.com/totk#All_Dungeons',
#      'type': 'per-game',
#      'rules': '* Runs must start from New Game or from a valid Intro Skip Save File in the Room of Awakening. Please see the Game Rules for more details.\r\n* For runs that start from New Game, timing starts from zero on hitting "start" in the main menu.\r\n* For runs that start from a valid Intro Skip Save File, timing starts from 6:40.867 on gaining control of Link in the Room of Awakening\r\n* Timing ends on touching Zelda\'s hand.\r\n* All temples must be beaten before beating Ganondorf.\r\n* All 5 vows must be collected before beating Ganondorf.\r\n* Phantom Ganon must be defeated in Hyrule Castle before beating Ganondorf.',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/wdmojz4k/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=wdmojz4k'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/wdmojz4k'}]}}},
#   {'place': 6,
#    'run': {'id': 'm70krj4y',
#     'weblink': 'https://www.speedrun.com/totk/run/m70krj4y',
#     'game': 'v1px9276',
#     'level': None,
#     'category': 'w20mopzk',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=GJcW0tlAL44'}]},
#     'comment': 'nice',
#     'status': {'status': 'verified',
#      'examiner': '0jm9drn8',
#      'verify-date': '2023-08-31T08:48:51Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2023-08-30',
#     'submitted': '2023-08-31T00:52:55Z',
#     'times': {'primary': 'PT43M47S',
#      'primary_t': 2627,
#      'realtime': 'PT43M47S',
#      'realtime_t': 2627,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '7m6ylw9p',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'jlz2gzyl': 'qj727k7q',
#      'p85p9dvl': 'qoxx2m5q',
#      'rn1g4gdn': '14ooyy0q',
#      'ql6wgzkn': 'qoxxdopq'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/m70krj4y'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/w20mopzk'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/7m6ylw9p'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/0jm9drn8'}]},
#    'game': {'data': {'id': 'v1px9276',
#      'names': {'international': 'The Legend of Zelda: Tears of the Kingdom',
#       'japanese': None,
#       'twitch': 'The Legend of Zelda: Tears of the Kingdom'},
#      'boostReceived': 42,
#      'boostDistinctDonors': 8,
#      'abbreviation': 'totk',
#      'weblink': 'https://www.speedrun.com/totk',
#      'discord': 'https://discord.gg/ZT5TG2KQnx',
#      'released': 2023,
#      'release-date': '2023-05-12',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['7m6ylw9p'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['9rnvvrnq'],
#      'engines': [],
#      'developers': ['rzjvw1zl'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'qjopo7x6': 'super-moderator',
#       '48g9l2xp': 'super-moderator',
#       'y8dk1vgj': 'super-moderator',
#       'dx3lkkqx': 'super-moderator',
#       'v8ll6l28': 'super-moderator',
#       '0jm9drn8': 'super-moderator',
#       'j4rlnov8': 'moderator',
#       'j5wv5zqj': 'super-moderator',
#       'xko2erk8': 'super-moderator',
#       'x3w1yq2j': 'moderator'},
#      'created': '2023-04-23T09:49:08Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/logo?v=2b85778'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/v1px9276/cover?v=9488997'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/favicon?v=5c5ccb8'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/1st?v=1510d39'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/2nd?v=9b28acb'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/3rd?v=fd63235'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/4th?v=ecb0db4'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/ywl1lxnr/background?v=61ec174'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=v1px9276'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1px9276/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/w20mopzk'}]}},
#    'category': {'data': {'id': 'w20mopzk',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/totk#Any',
#      'type': 'per-game',
#      'rules': '* Runs must start from New Game or from a valid Intro Skip Save File in the Room of Awakening. Please see the Game Rules for more details.\r\n* For runs that start from New Game, timing starts from zero on hitting "start" in the main menu.\r\n* For runs that start from a valid Intro Skip Save File, timing starts from 6:40.867 on gaining control of Link in the Room of Awakening\r\n* Timing ends on touching Zelda\'s hand.',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/w20mopzk'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1px9276'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/w20mopzk/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/w20mopzk/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=w20mopzk'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/v1px9276/category/w20mopzk'}]}}},
#   {'place': 78,
#    'run': {'id': 'ydj39g0y',
#     'weblink': 'https://www.speedrun.com/botw/run/ydj39g0y',
#     'game': '76rqjqd8',
#     'level': None,
#     'category': 'vdoq4xvk',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=xLzcXlHLs9g'}]},
#     'comment': 'last PB before the tears fall',
#     'status': {'status': 'verified',
#      'examiner': 'j5wv5zqj',
#      'verify-date': '2023-05-08T06:41:14Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2023-05-07',
#     'submitted': '2023-05-08T04:13:20Z',
#     'times': {'primary': 'PT27M56S',
#      'primary_t': 1676,
#      'realtime': 'PT27M56S',
#      'realtime_t': 1676,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '7m6ylw9p',
#      'emulated': False,
#      'region': 'pr184lqn'},
#     'splits': None,
#     'values': {'gnxrr7gn': '21dyvv31', 'j84q62n9': '9qjw2z01'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/ydj39g0y'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/vdoq4xvk'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/7m6ylw9p'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/pr184lqn'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/j5wv5zqj'}]},
#    'game': {'data': {'id': '76rqjqd8',
#      'names': {'international': 'The Legend of Zelda: Breath of the Wild',
#       'japanese': 'ゼルダの伝説\u3000ブレス オブ ザ ワイルド',
#       'twitch': 'The Legend of Zelda: Breath of the Wild'},
#      'boostReceived': 6,
#      'boostDistinctDonors': 5,
#      'abbreviation': 'botw',
#      'weblink': 'https://www.speedrun.com/botw',
#      'discord': 'https://discord.gg/rF4XeFC',
#      'released': 2017,
#      'release-date': '2017-03-03',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gejn93d', '7m6ylw9p'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': ['7d5owlnw', '61n9q2m0'],
#      'engines': [],
#      'developers': ['rzjvw1zl'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'v8l42vjm': 'super-moderator',
#       'kjpm9k5j': 'super-moderator',
#       'kj954qn8': 'super-moderator',
#       'pj06vr3j': 'super-moderator',
#       'dx3lkkqx': 'super-moderator',
#       'o86y750j': 'super-moderator',
#       'v8ll6l28': 'super-moderator',
#       'j5wv5zqj': 'super-moderator',
#       'jn3gz6dx': 'super-moderator',
#       'xko2erk8': 'super-moderator',
#       'j4rde6m8': 'super-moderator',
#       '8r71pydj': 'super-moderator',
#       '8en5ry28': 'super-moderator',
#       'xk4r497j': 'super-moderator'},
#      'created': '2017-02-14T01:37:43Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/logo?v=c297179'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/76rqjqd8/cover?v=4982d54'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/76rqjqd8/cover?v=4982d54'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/76rqjqd8/cover?v=4982d54'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/76rqjqd8/cover?v=4982d54'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/favicon?v=d9db41d'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/1st?v=58e09e4'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/2nd?v=e38009e'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/3rd?v=37f1524'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/4th?v=9ef7d49'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/6r5xld8m/background?v=845b145'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=76rqjqd8'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/76rqjqd8/category/vdoq4xvk'}]}},
#    'category': {'data': {'id': 'vdoq4xvk',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/botw#Any',
#      'type': 'per-game',
#      'rules': '**Any% Rules**\r\n* Runs must start from New Game.\r\n* Timing starts when gaining control of Link.\r\n* Timing ends when the last arrow makes contact with Dark Beast Ganon (first frame of the explosion animation)',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdoq4xvk'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/76rqjqd8'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdoq4xvk/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/vdoq4xvk/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=vdoq4xvk'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/76rqjqd8/category/vdoq4xvk'}]}}},
#   {'place': 1,
#    'run': {'id': 'z0jw07ey',
#     'weblink': 'https://www.speedrun.com/3dzelda/run/z0jw07ey',
#     'game': 'o6glv55d',
#     'level': None,
#     'category': 'jdre7rxk',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=WsRpmayBwqk'}]},
#     'comment': 'better',
#     'status': {'status': 'verified',
#      'examiner': '48g9l2xp',
#      'verify-date': '2023-05-06T14:29:11Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2023-04-20',
#     'submitted': '2023-04-28T15:05:41Z',
#     'times': {'primary': 'PT6H17M35S',
#      'primary_t': 22655,
#      'realtime': 'PT6H17M35S',
#      'realtime_t': 22655,
#      'realtime_noloads': 'PT6H12M28S',
#      'realtime_noloads_t': 22348,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': None, 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'rn14z4kn': 'gq74g6yq', 'p855wr08': '81pgzzk1'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/z0jw07ey'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o6glv55d'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/jdre7rxk'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/48g9l2xp'}]},
#    'game': {'data': {'id': 'o6glv55d',
#      'names': {'international': '3D Zelda Games',
#       'japanese': None,
#       'twitch': 'zeldaspeedruns'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': '3dzelda',
#      'weblink': 'https://www.speedrun.com/3dzelda',
#      'discord': 'https://discord.gg/zsr',
#      'released': 2019,
#      'release-date': '2019-02-14',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': True,
#      'gametypes': ['rj1dy1o8'],
#      'platforms': [],
#      'regions': [],
#      'genres': ['7d5owlnw'],
#      'engines': [],
#      'developers': ['xv6dvx62'],
#      'publishers': [],
#      'moderators': {'48g9l2xp': 'super-moderator'},
#      'created': '2019-02-14T18:45:11Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/zr2nkzor/logo?v=2def700'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o6glv55d/cover?v=2ac4dba'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/o6glv55d/cover?v=2ac4dba'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o6glv55d/cover?v=2ac4dba'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/o6glv55d/cover?v=2ac4dba'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/zr2nkzor/favicon?v=a5eaf49'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/zr2nkzor/background?v=07727b6'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/o6glv55d'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=o6glv55d'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/o6glv55d/levels'},
#       {'rel': 'categories',
# ...
#       'japanese': None,
#       'twitch': 'Harry Potter Category Extensions'},
#      'boostReceived': 8,
#      'boostDistinctDonors': 1,
#      'abbreviation': 'hpce',
#      'weblink': 'https://www.speedrun.com/hpce',
#      'discord': 'https://discord.gg/uTCQcE5Tmb',
#      'released': 2001,
#      'release-date': '2001-01-02',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': True},
#      'romhack': True,
#      'gametypes': ['53no817x', 'rj1dy1o8'],
#      'platforms': ['gde3g9k1',
#       '3167d6q2',
#       '7g6m8erk',
#       'n5e17e27',
#       'wxeod9rn',
#       'mx6pwe3g',
#       '5negk9y7',
#       'n568oevp',
#       'jm95zz9o',
#       '8gej2n93',
#       'v06dk3e4',
#       '7m6yvw6p',
#       'vm9v3ne3'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': [],
#      'engines': [],
#      'developers': [],
#      'publishers': [],
#      'moderators': {'zxz7o9jq': 'super-moderator',
#       'o8663w8z': 'moderator',
#       '98r10n6j': 'moderator',
#       '7j4ozn58': 'moderator',
#       '48gl4k2x': 'super-moderator',
#       'kjpd5k5j': 'moderator',
#       '8rpp3mgj': 'moderator',
#       '8l049d48': 'moderator',
#       'x3515o7j': 'moderator',
#       'j2yzy968': 'moderator',
#       'j5156pq8': 'moderator',
#       '8r2ko2qx': 'moderator',
#       '8q315lwj': 'moderator'},
#      'created': '2020-02-07T21:10:00Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/3dx2xov1/cover?v=0fcf05e'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/3dx2xov1/cover?v=0fcf05e'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/3dx2xov1/cover?v=0fcf05e'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/3dx2xov1/cover?v=0fcf05e'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/ywlkye87/favicon?v=f0963be'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/ywlkye87/1st?v=232aa99'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/ywlkye87/2nd?v=0921d7e'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/ywlkye87/3rd?v=a3f6271'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': None},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=3dx2xov1'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/15ndxp7r'},
#       {'rel': 'base-game',
#        'uri': 'https://www.speedrun.com/api/v1/games/v1plmp68'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/v1plmp68'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/3dx2xov1/category/xd1j7vwd'}]}},
#    'category': {'data': {'id': 'xd1j7vwd',
#      'name': '1PC',
#      'weblink': 'https://www.speedrun.com/hpce#1PC',
#      'type': 'per-game',
#      'rules': 'Submit Loadless Time given by Livesplit',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xd1j7vwd'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/3dx2xov1'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xd1j7vwd/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xd1j7vwd/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=xd1j7vwd'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/3dx2xov1/category/xd1j7vwd'}]}}},
#   {'place': 442,
#    'run': {'id': 'kz51dx5m',
#     'weblink': 'https://www.speedrun.com/oot/run/kz51dx5m',
#     'game': 'j1l9qz1g',
#     'level': None,
#     'category': 'z275w5k0',
#     'videos': None,
#     'comment': None,
#     'status': {'status': 'verified', 'examiner': None, 'verify-date': None},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2013-11-07',
#     'submitted': None,
#     'times': {'primary': 'PT22M31S',
#      'primary_t': 1351,
#      'realtime': 'PT22M31S',
#      'realtime_t': 1351,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': 'nzelreqp',
#      'emulated': False,
#      'region': 'o316x197'},
#     'splits': None,
#     'values': {'p854r2vl': '5q85yy6q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/kz51dx5m'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/z275w5k0'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/nzelreqp'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/o316x197'}]},
#    'game': {'data': {'id': 'j1l9qz1g',
#      'names': {'international': 'The Legend of Zelda: Ocarina of Time',
#       'japanese': 'ゼルダの伝説 時のオカリナ',
#       'twitch': 'The Legend of Zelda: Ocarina of Time'},
#      'boostReceived': 2,
#      'boostDistinctDonors': 2,
#      'abbreviation': 'oot',
#      'weblink': 'https://www.speedrun.com/oot',
#      'discord': 'https://discord.gg/7FYGh3d',
#      'released': 1998,
#      'release-date': '1998-11-21',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': True},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['w89rwelk',
#       '4p9z06rn',
#       'nzelreqp',
#       'v06dr394',
#       'p36nd598',
#       '7m6ylw9p'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197', 'mol4z19n'],
#      'genres': ['7d5owlnw'],
#      'engines': [],
#      'developers': ['xv6dvx62'],
#      'publishers': ['m0rvylrx'],
#      'moderators': {'qxk6p980': 'moderator',
#       'zxz55rxq': 'moderator',
#       'qxkge2j0': 'moderator',
#       'e8e5v680': 'super-moderator',
#       'y8dvrm86': 'moderator',
#       'qjnk6djm': 'moderator',
#       'qjn35kwx': 'super-moderator',
#       '7j423elx': 'moderator',
#       'kjppz52j': 'super-moderator',
#       'e8e3pdoj': 'super-moderator'},
#      'created': '2015-02-17T01:43:13Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/logo?v=05571f3'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/j1l9qz1g/cover?v=67e956c'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/j1l9qz1g/cover?v=67e956c'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/j1l9qz1g/cover?v=67e956c'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/j1l9qz1g/cover?v=67e956c'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/favicon?v=ce7e075'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/1st?v=d919fb9'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/2nd?v=27cc699'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/3rd?v=caa08b9'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/4th?v=8a4e198'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/g84jn383/background?v=f34de80'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=j1l9qz1g'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1l9qz1g/category/q25g198d'}]}},
#    'category': {'data': {'id': 'z275w5k0',
#      'name': 'Defeat Ganon',
#      'weblink': 'https://www.speedrun.com/oot#Defeat_Ganon',
#      'type': 'per-game',
#      'rules': '',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/z275w5k0'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/j1l9qz1g'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/z275w5k0/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/z275w5k0/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=z275w5k0'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1l9qz1g/category/z275w5k0'}]}}},
#   {'place': 13,
#    'run': {'id': '7z0q949m',
#     'weblink': 'https://www.speedrun.com/tww/run/7z0q949m',
#     'game': '4d709l17',
#     'level': None,
#     'category': 'xd18l428',
#     'videos': {'links': [{'uri': 'https://www.twitch.tv/gymnast86/v/49764051'}]},
#     'comment': "only video i have of me doing din's pearl",
#     'status': {'status': 'verified',
#      'examiner': 'v8l42vjm',
#      'verify-date': '2016-09-15T02:29:10Z'},
#     'players': [{'rel': 'user',
#       'id': 'v8l42vjm',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}],
#     'date': '2013-09-16',
#     'submitted': '2016-09-15T02:29:10Z',
#     'times': {'primary': 'PT51M50S',
#      'primary_t': 3110,
#      'realtime': 'PT51M50S',
#      'realtime_t': 3110,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '4p9z06rn',
#      'emulated': False,
#      'region': 'o316x197'},
#     'splits': None,
#     'values': {'0nw200nq': 'gq79nvlp', 'gnxwymg8': 'p12go84q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/7z0q949m'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/4d709l17'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/xd18l428'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/4p9z06rn'},
#      {'rel': 'region',
#       'uri': 'https://www.speedrun.com/api/v1/regions/o316x197'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/v8l42vjm'}]},
#    'game': {'data': {'id': '4d709l17',
#      'names': {'international': 'The Legend of Zelda: The Wind Waker',
#       'japanese': 'ゼルダの伝説 風のタクト',
#       'twitch': 'The Legend of Zelda: The Wind Waker'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': 'tww',
#      'weblink': 'https://www.speedrun.com/tww',
#      'discord': 'https://discord.gg/Sj5aehU',
#      'released': 2002,
#      'release-date': '2002-12-13',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': False,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': True},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['4p9z06rn'],
#      'regions': ['pr184lqn', 'e6lxy1dz', 'o316x197'],
#      'genres': [],
#      'engines': [],
#      'developers': [],
#      'publishers': [],
#      'moderators': {'368w238g': 'super-moderator',
#       'v8l42vjm': 'super-moderator',
#       'y8dyro86': 'super-moderator',
#       '5j5e7zjv': 'super-moderator',
#       '18qy30xn': 'super-moderator',
#       '5j59zrwx': 'super-moderator',
#       '8qzz39o8': 'super-moderator',
#       '8rp6do6j': 'super-moderator'},
#      'created': '2015-02-16T05:36:34Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/4d709l17/cover?v=c4aef72'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/4d709l17/cover?v=c4aef72'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/4d709l17/cover?v=c4aef72'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/4d709l17/cover?v=c4aef72'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/9wp30283/favicon?v=072ce60'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/9wp30283/1st?v=47f8143'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/9wp30283/2nd?v=a727e4a'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/9wp30283/3rd?v=fd7c9b1'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/9wp30283/background?v=b3520ee'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=4d709l17'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/j643gd7w'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d709l17/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/4d709l17/category/9d8x94w2'}]}},
#    'category': {'data': {'id': 'xd18l428',
#      'name': "Din's Pearl",
#      'weblink': 'https://www.speedrun.com/tww#Dins_Pearl',
#      'type': 'per-game',
#      'rules': "**Din's Pearl Rules:**\r\n\r\nComplete Dragon Roost Cavern.  \r\nTiming ends upon entering the warp at the end of Dragon Roost Cavern.  \r\nFor times below 50:00, video proof is required.  \r\nFor times below 50:00, emulators are banned.",
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': True,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xd18l428'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/4d709l17'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xd18l428/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xd18l428/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=xd18l428'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/4d709l17/category/xd18l428'}]}}}]}

# %%
response.json()['data'][0]['category']
# Out:
# {'data': {'id': 'vdo09m9d',
#   'name': 'Glitchless',
#   'weblink': 'https://www.speedrun.com/tphd#Glitchless',
#   'type': 'per-game',
#   'rules': '#Banned Glitches\r\n* Any Out of bounds glitches / skips \r\n* Gate Clipping \r\n* Rupee / Midna Diving \r\n* Epona Slide \r\n* Sword & Shield Skip \r\n* Rocket Link \r\n* Moon Boots\r\n* Text Displacement\r\n* Using normal bombs in water \r\n* Long Jump Attack with Boomerang\r\n(enemy LJAs are allowed)\r\n* Keese LJAs\r\n* Super Jumps\r\n* Infinite Soup\r\n* Super Sliding\r\n* Early Gale Boomerang \r\n* Bombhouse Skip\r\n* Stealing the Bomb Bag \r\n* Pot Clip through Rock to Deku Toad \r\n* Floor Clipping \r\n* Opening Doors Backwards\r\n* Early City in the Sky (Statue clip) \r\n* Early Boss Key in CitS \r\n* Aeralfos Skip \r\n* Skipping Darknut Fight in Hyrule Castle',
#   'players': {'type': 'exactly', 'value': 1},
#   'miscellaneous': False,
#   'links': [{'rel': 'self',
#     'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d'},
#    {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#    {'rel': 'variables',
#     'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/variables'},
#    {'rel': 'records',
#     'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/records'},
#    {'rel': 'runs',
#     'uri': 'https://www.speedrun.com/api/v1/runs?category=vdo09m9d'},
#    {'rel': 'leaderboard',
#     'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zx70d0/category/vdo09m9d'}]}}

# %%
temp_df = pd.DataFrame(response.json()['data'])

# %%
pd.json_normalize(response.json()['data'])
# Out:
#     place    run.id                                 run.weblink  run.game  \
# 0       1  z5835njz  https://www.speedrun.com/tphd/run/z5835njz  m1zx70d0
# 1       1  yldv32xm  https://www.speedrun.com/tphd/run/yldv32xm  m1zx70d0
# 2       1  mrvj338z  https://www.speedrun.com/totk/run/mrvj338z  v1px9276
# 3       1  y6q1ld0z  https://www.speedrun.com/totk/run/y6q1ld0z  v1px9276
# 4       1  y4kg022m  https://www.speedrun.com/totk/run/y4kg022m  v1px9276
# ..    ...       ...                                         ...       ...
# 67    134  9mr81ogy    https://www.speedrun.com/mm/run/9mr81ogy  268zey6p
# 68    201  8y89jkdm   https://www.speedrun.com/oot/run/8y89jkdm  j1l9qz1g
# 69     31  y410ndky  https://www.speedrun.com/hpce/run/y410ndky  3dx2xov1
# 70    442  kz51dx5m   https://www.speedrun.com/oot/run/kz51dx5m  j1l9qz1g
# 71     13  7z0q949m   https://www.speedrun.com/tww/run/7z0q949m  4d709l17
#
#    run.level run.category                                   run.videos.links  \
# 0       None     vdo09m9d  [{'uri': 'https://www.youtube.com/watch?v=OUIz...
# 1       None     vdo09m9d  [{'uri': 'https://www.youtube.com/watch?v=OUIz...
# 2       None     wdmojz4k  [{'uri': 'https://www.youtube.com/watch?v=J4d7...
# 3       None     wdmojz4k  [{'uri': 'https://www.youtube.com/watch?v=NcNC...
# 4       None     wdmojz4k          [{'uri': 'https://youtu.be/cyXhoWTqIM0'}]
# ..       ...          ...                                                ...
# 67      None     jdzlw4r2  [{'uri': 'https://www.youtube.com/watch?v=yzdb...
# 68      None     q255jw2o  [{'uri': 'https://www.twitch.tv/gymnast86/v/47...
# 69      None     xd1j7vwd  [{'uri': 'https://www.youtube.com/watch?v=zuox...
# 70      None     z275w5k0                                                NaN
# 71      None     xd18l428  [{'uri': 'https://www.twitch.tv/gymnast86/v/49...
#
#                                           run.comment run.status.status  \
# 0                     Bad Arbiter's, City, and Zelda           verified
# 1               Slow start, but otherwise mostly good          verified
# 2                                                nice          verified
# 3                                     bad wind temple          verified
# 4                                         Nice middle          verified
# ..                                                ...               ...
# 67                                               None          verified
# 68                                               None          verified
# 69  This run was kinda bad but I'll take it. The b...          verified
# 70                                               None          verified
# 71          only video i have of me doing din's pearl          verified
#
#    run.status.examiner  ... game.data.moderators.8rpp3mgj  \
# 0             y8dqky5j  ...                           NaN
# 1             y8dqky5j  ...                           NaN
# 2             xko2erk8  ...                           NaN
# 3             x3w1yq2j  ...                           NaN
# 4             x3w1yq2j  ...                           NaN
# ..                 ...  ...                           ...
# 67            zx7mo6x7  ...                           NaN
# 68                None  ...                           NaN
# 69            o8663w8z  ...                     moderator
# 70                None  ...                           NaN
# 71            v8l42vjm  ...                           NaN
#
#    game.data.moderators.8l049d48 game.data.moderators.x3515o7j  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ..                           ...                           ...
# 67                           NaN                           NaN
# 68                           NaN                           NaN
# 69                     moderator                     moderator
# 70                           NaN                           NaN
# 71                           NaN                           NaN
#
#    game.data.moderators.j2yzy968 game.data.moderators.j5156pq8  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
# 3                            NaN                           NaN
# 4                            NaN                           NaN
# ..                           ...                           ...
# 67                           NaN                           NaN
# 68                           NaN                           NaN
# 69                     moderator                     moderator
# 70                           NaN                           NaN
# 71                           NaN                           NaN
#
#     game.data.moderators.8r2ko2qx game.data.moderators.8q315lwj  run.videos  \
# 0                             NaN                           NaN         NaN
# 1                             NaN                           NaN         NaN
# 2                             NaN                           NaN         NaN
# 3                             NaN                           NaN         NaN
# 4                             NaN                           NaN         NaN
# ..                            ...                           ...         ...
# 67                            NaN                           NaN         NaN
# 68                            NaN                           NaN         NaN
# 69                      moderator                     moderator         NaN
# 70                            NaN                           NaN         NaN
# 71                            NaN                           NaN         NaN
#
#    run.values.p854r2vl  run.values.gnxwymg8
# 0                  NaN                  NaN
# 1                  NaN                  NaN
# 2                  NaN                  NaN
# 3                  NaN                  NaN
# 4                  NaN                  NaN
# ..                 ...                  ...
# 67                 NaN                  NaN
# 68                 NaN                  NaN
# 69                 NaN                  NaN
# 70            5q85yy6q                  NaN
# 71                 NaN             p12go84q
#
# [72 rows x 236 columns]

# %%
runs_df = pd.DataFrame({'runner':[],'place':[],'game':[],'category':[],'time':[],'date':[]})
runs_df
# Out:
# Empty DataFrame
# Columns: [runner, place, game, category, time, date]
# Index: []

# %%
response.json()['data'][0]['place']
# Out:
# 1

# %%
response.json()['data'][0]['game']['data']['names']['twitch']
# Out:
# 'The Legend of Zelda: Twilight Princess HD'

# %%
response.json()['data'][0]['category']['data']['name']
# Out:
# 'Glitchless'

# %%
response.json()['data'][0]['category']
# Out:
# {'data': {'id': 'vdo09m9d',
#   'name': 'Glitchless',
#   'weblink': 'https://www.speedrun.com/tphd#Glitchless',
#   'type': 'per-game',
#   'rules': '#Banned Glitches\r\n* Any Out of bounds glitches / skips \r\n* Gate Clipping \r\n* Rupee / Midna Diving \r\n* Epona Slide \r\n* Sword & Shield Skip \r\n* Rocket Link \r\n* Moon Boots\r\n* Text Displacement\r\n* Using normal bombs in water \r\n* Long Jump Attack with Boomerang\r\n(enemy LJAs are allowed)\r\n* Keese LJAs\r\n* Super Jumps\r\n* Infinite Soup\r\n* Super Sliding\r\n* Early Gale Boomerang \r\n* Bombhouse Skip\r\n* Stealing the Bomb Bag \r\n* Pot Clip through Rock to Deku Toad \r\n* Floor Clipping \r\n* Opening Doors Backwards\r\n* Early City in the Sky (Statue clip) \r\n* Early Boss Key in CitS \r\n* Aeralfos Skip \r\n* Skipping Darknut Fight in Hyrule Castle',
#   'players': {'type': 'exactly', 'value': 1},
#   'miscellaneous': False,
#   'links': [{'rel': 'self',
#     'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d'},
#    {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/m1zx70d0'},
#    {'rel': 'variables',
#     'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/variables'},
#    {'rel': 'records',
#     'uri': 'https://www.speedrun.com/api/v1/categories/vdo09m9d/records'},
#    {'rel': 'runs',
#     'uri': 'https://www.speedrun.com/api/v1/runs?category=vdo09m9d'},
#    {'rel': 'leaderboard',
#     'uri': 'https://www.speedrun.com/api/v1/leaderboards/m1zx70d0/category/vdo09m9d'}]}}

# %%
response.json()['data'][0]['run']['times']['primary_t']
# Out:
# 18101

# %%
response.json()['data'][0]['run']['date']
# Out:
# '2024-03-11'

# %%
runners_list = ['CaptainEzekiel', 'spicee', 'maeeeeee', 'gymnast86', 'Zic3']

# %% [markdown]
# response = requests.get('https://www.speedrun.com/api/v1/users/gymnast86/personal-bests?embed=game,category')

# %%
entries = []
for ind in list(range(0,len(response.json()['data']))):
    entry = pd.DataFrame({
        'runner' : ['gymnast86'],
        'place' : [response.json()['data'][ind]['place']],
        'game' : [response.json()['data'][ind]['game']['data']['names']['twitch']],
        'category' : [response.json()['data'][ind]['category']['data']['name']],
        'time' : [response.json()['data'][ind]['run']['times']['primary_t']],
        'date' : [response.json()['data'][ind]['run']['date']]
    })
    entries.append(entry)
runs_df = pd.concat(entries)
runs_df
# Out:
#        runner  place                                       game      category  \
# 0   gymnast86      1  The Legend of Zelda: Twilight Princess HD    Glitchless
# 0   gymnast86      1  The Legend of Zelda: Twilight Princess HD    Glitchless
# 0   gymnast86      1  The Legend of Zelda: Tears of the Kingdom  All Dungeons
# 0   gymnast86      1  The Legend of Zelda: Tears of the Kingdom  All Dungeons
# 0   gymnast86      1  The Legend of Zelda: Tears of the Kingdom  All Dungeons
# ..        ...    ...                                        ...           ...
# 0   gymnast86    134         The Legend of Zelda: Majora's Mask          Any%
# 0   gymnast86    201       The Legend of Zelda: Ocarina of Time          100%
# 0   gymnast86     31           Harry Potter Category Extensions           1PC
# 0   gymnast86    442       The Legend of Zelda: Ocarina of Time  Defeat Ganon
# 0   gymnast86     13        The Legend of Zelda: The Wind Waker   Din's Pearl
#
#      time        date
# 0   18101  2024-03-11
# 0    8894  2024-03-11
# 0    9557  2024-02-03
# 0    9620  2024-01-31
# 0    9750  2023-11-29
# ..    ...         ...
# 0    6187  2014-12-05
# 0   38836  2014-03-29
# 0    5870  2014-03-13
# 0    1351  2013-11-07
# 0    3110  2013-09-16
#
# [72 rows x 6 columns]

# %%
def get_response(x):
    url = ('https://www.speedrun.com/api/v1/users/')+x+('/personal-bests?embed=game,category')
    
    response = requests.get(url)
    
    return response

# %%
response = requests.get('https://www.speedrun.com/api/v1/users//personal-bests?embed=game,category')
response
# Out:
# <Response [200]>

# %%
get_reponse('spicee')
# Out:
# {'data': [{'place': 1,
#    'run': {'id': 'yo07kp7y',
#     'weblink': 'https://www.speedrun.com/sottr/run/yo07kp7y',
#     'game': 'y654or8d',
#     'level': None,
#     'category': 'zd37rz82',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=6h4kchlhgsE'}]},
#     'comment': None,
#     'status': {'status': 'verified',
#      'examiner': 'o867z05j',
#      'verify-date': '2024-04-12T12:56:34Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2024-03-26',
#     'submitted': '2024-03-26T13:24:20Z',
#     'times': {'primary': 'PT42M47S',
#      'primary_t': 2567,
#      'realtime': 'PT43M25S',
#      'realtime_t': 2605,
#      'realtime_noloads': 'PT42M47S',
#      'realtime_noloads_t': 2567,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'2lgzw038': '0q58k9nq', 'onv2jpwl': 'zqo35z2q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/yo07kp7y'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/y654or8d'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/zd37rz82'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/o867z05j'}]},
#    'game': {'data': {'id': 'y654or8d',
#      'names': {'international': 'Shadow of the Tomb Raider',
#       'japanese': None,
#       'twitch': 'Shadow of the Tomb Raider'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': 'sottr',
#      'weblink': 'https://www.speedrun.com/sottr',
#      'discord': 'https://discord.gg/011hZixyZfK5g61NL',
#      'released': 2018,
#      'release-date': '2018-09-14',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads', 'ingame'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       'o064z1e3',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': [],
#      'genres': ['9rnvvrnq'],
#      'engines': ['v93drm5y'],
#      'developers': ['93zy8pe4', '81e7mde7', '4epy8rer'],
#      'publishers': ['lkry9gnv'],
#      'moderators': {'1xyy6vxr': 'super-moderator',
#       'o86v653j': 'super-moderator',
#       '7j4rzdw8': 'super-moderator',
#       '98r3yv38': 'super-moderator',
#       'o867z05j': 'super-moderator',
#       'j0n44738': 'moderator'},
#      'created': '2018-09-11T20:10:04Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/y654or8d/cover?v=5fdcba6'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/y654or8d/cover?v=5fdcba6'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/y654or8d/cover?v=5fdcba6'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/y654or8d/cover?v=5fdcba6'},
#       'icon': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/2wo190re/background?v=990f0e4'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=y654or8d'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/d5nkwgn9'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/y654or8d/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/y654or8d/category/zd37rz82'}]}},
#    'category': {'data': {'id': 'zd37rz82',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/sottr#Any',
#      'type': 'per-game',
#      'rules': '**Basic rules are found on the Game Rules tab.**\r\n\r\n- DLCs aren\'t allowed.\r\n\r\n- New Game Plus is not allowed.\r\n\r\n----\r\n\r\n###### **TIMING**\r\n\r\nTime starts when you select difficulty. \r\nAlternatively: You may use a save to skip the intro from the checkpoint that triggers right after Lara\'s line: "They\'ve entered the dig site". If you prefer skipping the intro:\r\n- PC timer must be set on 12:30. If correct options are ticked under [EDIT SPLITS] on LiveSplit the IGT should change to 5:20. Save-file that is loaded from is available under Resources tab.\r\n- Console timer is 12:20, as the possibility of achieving that time is proven by the console runners. \r\n\r\nTime ends when the last knife stab occurs with Amaru.\r\n\r\n - Default timing method is Time w/o Loads for PC.\r\n - Default timing method is Time with Loads for Consoles.',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/zd37rz82'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/y654or8d'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/zd37rz82/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/zd37rz82/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=zd37rz82'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/y654or8d/category/zd37rz82'}]}}},
#   {'place': 1,
#    'run': {'id': 'zq84648z',
#     'weblink': 'https://www.speedrun.com/tr2013/run/zq84648z',
#     'game': '576rvq18',
#     'level': None,
#     'category': 'mkeojxd6',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=-jen-W6jMOo'}]},
#     'comment': None,
#     'status': {'status': 'verified',
#      'examiner': '8e6q697j',
#      'verify-date': '2024-03-15T03:14:53Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2024-03-13',
#     'submitted': '2024-03-13T12:19:53Z',
#     'times': {'primary': 'PT53M9S',
#      'primary_t': 3189,
#      'realtime': 'PT59M30S',
#      'realtime_t': 3570,
#      'realtime_noloads': 'PT53M9S',
#      'realtime_noloads_t': 3189,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'gnx0mzxn': '9qjzo5o1',
#      'ylpkdk8g': '81w4dg6q',
#      'wlemkrn6': 'p129zk4l'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/zq84648z'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/576rvq18'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/mkeojxd6'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/8e6q697j'}]},
#    'game': {'data': {'id': '576rvq18',
#      'names': {'international': 'Tomb Raider (2013)',
#       'japanese': None,
#       'twitch': 'Tomb Raider'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': 'tr2013',
#      'weblink': 'https://www.speedrun.com/tr2013',
#      'discord': 'https://discord.gg/011hZixyZfK5g61NL',
#      'released': 2013,
#      'release-date': '2013-03-05',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': True},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['mx6pwe3g',
#       'n568oevp',
#       'nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': [],
#      'genres': ['9rnvvrnq'],
#      'engines': ['v93drm5y'],
#      'developers': ['81e7mde7', '93zy8pe4', '4epy8rer'],
#      'publishers': ['lkry9gnv'],
#      'moderators': {'qjo3zej6': 'super-moderator',
#       '1xyy6vxr': 'super-moderator',
#       'o86v653j': 'super-moderator',
#       '7j4rzdw8': 'super-moderator',
#       '98r3yv38': 'super-moderator',
#       'o867z05j': 'super-moderator',
#       'j0n44738': 'super-moderator',
#       '8e6q697j': 'moderator'},
#      'created': None,
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/576rvq18/cover?v=10e3260'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/576rvq18/cover?v=10e3260'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/576rvq18/cover?v=10e3260'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/576rvq18/cover?v=10e3260'},
#       'icon': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/zr0o72or/background?v=3a0b061'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=576rvq18'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/d5nkwgn9'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/576rvq18/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/576rvq18/category/mkeojxd6'}]}},
#    'category': {'data': {'id': 'mkeojxd6',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/tr2013#Any',
#      'type': 'per-game',
#      'rules': "**Basic rules are found on the Game Rules tab.**\r\n\r\n- All DLCs except DLCs for Lara's outfits are banned.",
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/mkeojxd6'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/576rvq18'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/mkeojxd6/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/mkeojxd6/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=mkeojxd6'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/576rvq18/category/mkeojxd6'}]}}},
#   {'place': 4,
#    'run': {'id': 'yd2gxowm',
#     'weblink': 'https://www.speedrun.com/re4r/run/yd2gxowm',
#     'game': 'o1yjv5o1',
#     'level': None,
#     'category': '7dgepwg2',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=mu-Sp36mdl4'}]},
#     'comment': None,
#     'status': {'status': 'verified',
#      'examiner': 'x7q7n2y8',
#      'verify-date': '2023-12-05T22:49:21Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2023-12-05',
#     'submitted': '2023-12-05T07:00:45Z',
#     'times': {'primary': 'PT42M26S',
#      'primary_t': 2546,
#      'realtime': 'PT42M26S',
#      'realtime_t': 2546,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'rn1jrq1n': '1w4vyovq', 'dlo9wqrl': 'qoxmrj2q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/yd2gxowm'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/x7q7n2y8'}]},
#    'game': {'data': {'id': 'o1yjv5o1',
#      'names': {'international': 'Resident Evil 4 (2023)',
#       'japanese': None,
#       'twitch': 'Resident Evil 4'},
#      'boostReceived': 17,
#      'boostDistinctDonors': 8,
#      'abbreviation': 're4r',
#      'weblink': 'https://www.speedrun.com/re4r',
#      'discord': 'https://discord.gg/X82X7cbjeC',
#      'released': 2023,
#      'release-date': '2023-03-15',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': ['pr184lqn',
#       'e6lxy1dz',
#       'o316x197',
#       'mol4z19n',
#       'p2g50lnk',
#       'ypl25l47'],
#      'genres': ['oy5gp5e3'],
#      'engines': ['r81p4m1d'],
#      'developers': ['myzo3pzq'],
#      'publishers': ['k564wnw1'],
#      'moderators': {'o8674wjz': 'super-moderator',
#       'pj05zm8w': 'super-moderator',
#       '48ge6kyj': 'super-moderator',
#       '68w6ld4j': 'super-moderator',
#       'e8erpl6j': 'super-moderator',
#       'v81l19rx': 'super-moderator',
#       '8qz7dy08': 'moderator',
#       'x35opl7j': 'super-moderator',
#       '8r7k6kqj': 'super-moderator',
#       'jmp1ldej': 'super-moderator',
#       '86nqdq5x': 'super-moderator',
#       '8g56kg2j': 'super-moderator',
#       'jm31r5z8': 'super-moderator',
#       'jnpnodq8': 'super-moderator'},
#      'created': '2023-02-20T19:29:33Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/favicon?v=33842fb'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/1st?v=a57e2f0'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/2nd?v=1fd4c62'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/3rd?v=47b5c10'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/background?v=0d0166b'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=o1yjv5o1'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/gnyj1xnx'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1yjv5o1/category/jdz0l4r2'}]}},
#    'category': {'data': {'id': '7dgepwg2',
#      'name': 'Separate Ways',
#      'weblink': 'https://www.speedrun.com/re4r#separate-ways-any',
#      'type': 'per-game',
#      'rules': '- Run must be started from a New Game file.\n- No NG+ items, unlocks or DLC items are allowed. This includes:\n- Any accessories that have an ability/advantage including sunglasses.\n- Charms and cases bought from the merchant are allowed\n- FPS swapping is banned\n- All Out of Bounds are allowed. DA0 is banned.\n- You are allowed to spend up to a maximum of 3 minutes in the pause menu for the duration of the run, this may be used for toilet breaks etc.',
#      'players': {'type': 'up-to', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=7dgepwg2'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1yjv5o1/category/7dgepwg2'}]}}},
#   {'place': 2,
#    'run': {'id': 'zxw8kxkm',
#     'weblink': 'https://www.speedrun.com/lies_of_p/run/zxw8kxkm',
#     'game': '4d7n7wl6',
#     'level': None,
#     'category': 'mke1p392',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=nNewGlXGn8I'}]},
#     'comment': '[Mod comment: ![:CatGoesFishing:](https://cdn.discordapp.com/emojis/1160304474301136997.webp?size=44&quality=lossless)![:Fishinge:](https://cdn.discordapp.com/emojis/1153348067752415372.webp?size=44&quality=lossless)![:FridgeFishinge:](https://cdn.discordapp.com/emojis/1160303867129516053.webp?size=44&quality=lossless)]',
#     'status': {'status': 'verified',
#      'examiner': 'jpmr5qyj',
#      'verify-date': '2023-11-25T14:51:31Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2023-11-22',
#     'submitted': '2023-11-22T22:02:21Z',
#     'times': {'primary': 'PT42M37S',
#      'primary_t': 2557,
#      'realtime': 'PT42M37S',
#      'realtime_t': 2557,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'ylpyv4vl': 'qj7ggjoq',
#      '0nwm2qk8': 'lmoddz01',
#      'ylq3ge78': 'q65yxz3l',
#      '2lgez738': 'le2eeg6l',
#      '789vky6n': 'qox55d4q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/zxw8kxkm'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/mke1p392'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/jpmr5qyj'}]},
#    'game': {'data': {'id': '4d7n7wl6',
#      'names': {'international': 'Lies of P',
#       'japanese': None,
#       'twitch': 'Lies of P'},
#      'boostReceived': 2,
#      'boostDistinctDonors': 2,
#      'abbreviation': 'lies_of_p',
#      'weblink': 'https://www.speedrun.com/lies_of_p',
#      'discord': 'https://discord.gg/wzSkfGTTnr',
#      'released': 2023,
#      'release-date': '2023-06-08',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': [],
#      'genres': [],
#      'engines': [],
#      'developers': [],
#      'publishers': [],
#      'moderators': {'kj9mo9wx': 'super-moderator',
#       '86nr4p5x': 'super-moderator',
#       'jpmr5qyj': 'super-moderator',
#       'j9r3rvwj': 'super-moderator',
#       '8lozok28': 'moderator',
#       'x772r3qx': 'super-moderator'},
#      'created': '2023-06-24T02:45:54Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'icon': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/1st?v=996d77b'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/2nd?v=9a44ebd'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/3rd?v=0037c3f'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/4th?v=8415882'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/background?v=3b623d1'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=4d7n7wl6'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/4d7n7wl6/category/mke1p392'}]}},
#    'category': {'data': {'id': 'mke1p392',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/lies_of_p#any',
#      'type': 'per-game',
#      'rules': 'in glitchless it is prohibited:\n\n- Boss skips\n- Out of Bounds\n- Any new tech that is found that would be considered a glitch, such as move swaps, instant kills, etc.\n- it is not allowed to breaking the AI of the bosses/minibosses',
#      'players': {'type': 'up-to', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/mke1p392'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/mke1p392/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/mke1p392/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=mke1p392'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/4d7n7wl6/category/mke1p392'}]}}},
#   {'place': 1,
#    'run': {'id': 'y4kqo8km',
#     'weblink': 'https://www.speedrun.com/lies_of_p/run/y4kqo8km',
#     'game': '4d7n7wl6',
#     'level': None,
#     'category': 'xk9z63x2',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=MlfgcLGScFA'}]},
#     'comment': '[Mod comment: ![:CatGoesFishing:](https://cdn.discordapp.com/emojis/1160304474301136997.webp?size=44&quality=lossless)![:Fishinge:](https://cdn.discordapp.com/emojis/1153348067752415372.webp?size=44&quality=lossless)![:FridgeFishinge:](https://cdn.discordapp.com/emojis/1160303867129516053.webp?size=44&quality=lossless)]',
#     'status': {'status': 'verified',
#      'examiner': 'jpmr5qyj',
#      'verify-date': '2023-11-22T03:51:21Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2023-11-18',
#     'submitted': '2023-11-18T14:20:48Z',
#     'times': {'primary': 'PT1H9M54S',
#      'primary_t': 4194,
#      'realtime': 'PT1H9M54S',
#      'realtime_t': 4194,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'ylq3ge78': 'q65yxz3l',
#      '68k1m9yl': '12v22e2q',
#      'j84jk4j8': 'qkezzk4q',
#      'rn1y13kn': '1gnxxrol',
#      'p85y910l': 'lr355wwl'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/y4kqo8km'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/xk9z63x2'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/jpmr5qyj'}]},
#    'game': {'data': {'id': '4d7n7wl6',
#      'names': {'international': 'Lies of P',
#       'japanese': None,
#       'twitch': 'Lies of P'},
#      'boostReceived': 2,
#      'boostDistinctDonors': 2,
#      'abbreviation': 'lies_of_p',
#      'weblink': 'https://www.speedrun.com/lies_of_p',
#      'discord': 'https://discord.gg/wzSkfGTTnr',
#      'released': 2023,
#      'release-date': '2023-06-08',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': [],
#      'genres': [],
#      'engines': [],
#      'developers': [],
#      'publishers': [],
#      'moderators': {'kj9mo9wx': 'super-moderator',
#       '86nr4p5x': 'super-moderator',
#       'jpmr5qyj': 'super-moderator',
#       'j9r3rvwj': 'super-moderator',
#       '8lozok28': 'moderator',
#       'x772r3qx': 'super-moderator'},
#      'created': '2023-06-24T02:45:54Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/4d7n7wl6/cover?v=c48dad7'},
#       'icon': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/1st?v=996d77b'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/2nd?v=9a44ebd'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/3rd?v=0037c3f'},
#       'trophy-4th': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/4th?v=8415882'},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/q8gyoqd8/background?v=3b623d1'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=4d7n7wl6'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/4d7n7wl6/category/mke1p392'}]}},
#    'category': {'data': {'id': 'xk9z63x2',
#      'name': 'All Ergo Bosses',
#      'weblink': 'https://www.speedrun.com/lies_of_p#all-ergo-bosses',
#      'type': 'per-game',
#      'rules': '',
#      'players': {'type': 'up-to', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xk9z63x2'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/4d7n7wl6'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xk9z63x2/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/xk9z63x2/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=xk9z63x2'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/4d7n7wl6/category/xk9z63x2'}]}}},
#   {'place': 1,
#    'run': {'id': 'y2k55n9y',
#     'weblink': 'https://www.speedrun.com/re4r/run/y2k55n9y',
#     'game': 'o1yjv5o1',
#     'level': None,
#     'category': '7dgepwg2',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=XZpnMC_AFkQ'}]},
#     'comment': None,
#     'status': {'status': 'verified',
#      'examiner': 'e8erpl6j',
#      'verify-date': '2023-10-02T03:46:18Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2023-10-02',
#     'submitted': '2023-10-02T03:44:47Z',
#     'times': {'primary': 'PT46M3S',
#      'primary_t': 2763,
#      'realtime': 'PT46M3S',
#      'realtime_t': 2763,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'rn1jrq1n': '1w4vyovq', 'dlo9wqrl': 'qoxmrj2q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/y2k55n9y'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/e8erpl6j'}]},
#    'game': {'data': {'id': 'o1yjv5o1',
#      'names': {'international': 'Resident Evil 4 (2023)',
#       'japanese': None,
#       'twitch': 'Resident Evil 4'},
#      'boostReceived': 17,
#      'boostDistinctDonors': 8,
#      'abbreviation': 're4r',
#      'weblink': 'https://www.speedrun.com/re4r',
#      'discord': 'https://discord.gg/X82X7cbjeC',
#      'released': 2023,
#      'release-date': '2023-03-15',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': ['pr184lqn',
#       'e6lxy1dz',
#       'o316x197',
#       'mol4z19n',
#       'p2g50lnk',
#       'ypl25l47'],
#      'genres': ['oy5gp5e3'],
#      'engines': ['r81p4m1d'],
#      'developers': ['myzo3pzq'],
#      'publishers': ['k564wnw1'],
#      'moderators': {'o8674wjz': 'super-moderator',
#       'pj05zm8w': 'super-moderator',
#       '48ge6kyj': 'super-moderator',
#       '68w6ld4j': 'super-moderator',
#       'e8erpl6j': 'super-moderator',
#       'v81l19rx': 'super-moderator',
#       '8qz7dy08': 'moderator',
#       'x35opl7j': 'super-moderator',
#       '8r7k6kqj': 'super-moderator',
#       'jmp1ldej': 'super-moderator',
#       '86nqdq5x': 'super-moderator',
#       '8g56kg2j': 'super-moderator',
#       'jm31r5z8': 'super-moderator',
#       'jnpnodq8': 'super-moderator'},
#      'created': '2023-02-20T19:29:33Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/favicon?v=33842fb'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/1st?v=a57e2f0'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/2nd?v=1fd4c62'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/3rd?v=47b5c10'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/background?v=0d0166b'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=o1yjv5o1'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/gnyj1xnx'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1yjv5o1/category/jdz0l4r2'}]}},
#    'category': {'data': {'id': '7dgepwg2',
#      'name': 'Separate Ways',
#      'weblink': 'https://www.speedrun.com/re4r#separate-ways-any',
#      'type': 'per-game',
#      'rules': '- Run must be started from a New Game file.\n- No NG+ items, unlocks or DLC items are allowed. This includes:\n- Any accessories that have an ability/advantage including sunglasses.\n- Charms and cases bought from the merchant are allowed\n- FPS swapping is banned\n- All Out of Bounds are allowed. DA0 is banned.\n- You are allowed to spend up to a maximum of 3 minutes in the pause menu for the duration of the run, this may be used for toilet breaks etc.',
#      'players': {'type': 'up-to', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgepwg2/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=7dgepwg2'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1yjv5o1/category/7dgepwg2'}]}}},
#   {'place': 1,
#    'run': {'id': 'z1k1wk7y',
#     'weblink': 'https://www.speedrun.com/efli/run/z1k1wk7y',
#     'game': 'o1y3j526',
#     'level': None,
#     'category': 'zd3m4782',
#     'videos': {'links': [{'uri': 'https://www.twitch.tv/videos/1933764109'}]},
#     'comment': None,
#     'status': {'status': 'verified',
#      'examiner': 'qjn3npwx',
#      'verify-date': '2023-09-30T18:14:04Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2023-09-24',
#     'submitted': '2023-09-24T05:52:05Z',
#     'times': {'primary': 'PT7M50.130S',
#      'primary_t': 470.13,
#      'realtime': 'PT7M50.130S',
#      'realtime_t': 470.13,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/z1k1wk7y'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/zd3m4782'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/qjn3npwx'}]},
#    'game': {'data': {'id': 'o1y3j526',
#      'names': {'international': 'Escape From Lavender Island',
#       'japanese': None,
#       'twitch': 'Escape From Lavender Island'},
#      'boostReceived': 10,
#      'boostDistinctDonors': 4,
#      'abbreviation': 'efli',
#      'weblink': 'https://www.speedrun.com/efli',
#      'discord': 'https://discord.gg/fYbQzA9KvV',
#      'released': 2023,
#      'release-date': '2023-09-01',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gej2n93'],
#      'regions': [],
#      'genres': [],
#      'engines': [],
#      'developers': [],
#      'publishers': [],
#      'moderators': {'e8e6r7j0': 'super-moderator',
#       'qjn3npwx': 'super-moderator',
#       'pj0vo5rx': 'moderator',
#       'zx7ek1q8': 'super-moderator',
#       'zxzrvke8': 'super-moderator',
#       'xz99dpe8': 'moderator',
#       'xy5m9zv8': 'moderator',
#       'j92ergo8': 'super-moderator'},
#      'created': '2023-09-05T14:46:33Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o1y3j526/cover?v=2ea84f3'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/o1y3j526/cover?v=2ea84f3'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o1y3j526/cover?v=2ea84f3'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/o1y3j526/cover?v=2ea84f3'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/qrvlemmw/favicon?v=2f23fbc'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/qrvlemmw/background?v=68d2871'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=o1y3j526'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1y3j526/category/zd3m4782'}]}},
#    'category': {'data': {'id': 'zd3m4782',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/efli#any',
#      'type': 'per-game',
#      'rules': 'You can skip neighborhoods.',
#      'players': {'type': 'up-to', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/zd3m4782'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1y3j526'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/zd3m4782/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/zd3m4782/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=zd3m4782'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1y3j526/category/zd3m4782'}]}}},
#   {'place': 4,
#    'run': {'id': 'melrw73z',
#     'weblink': 'https://www.speedrun.com/re4r/run/melrw73z',
#     'game': 'o1yjv5o1',
#     'level': None,
#     'category': 'jdz0l4r2',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=BbD5WdDw8IE'}]},
#     'comment': None,
#     'status': {'status': 'verified',
#      'examiner': 'x7q7n2y8',
#      'verify-date': '2023-09-11T22:58:06Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2023-09-03',
#     'submitted': '2023-09-03T10:29:12Z',
#     'times': {'primary': 'PT1H43M53S',
#      'primary_t': 6233,
#      'realtime': 'PT1H43M53S',
#      'realtime_t': 6233,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'rn1jrq1n': '1w4vyovq', 'p855xj38': 'q8k2033q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/melrw73z'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/jdz0l4r2'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/x7q7n2y8'}]},
#    'game': {'data': {'id': 'o1yjv5o1',
#      'names': {'international': 'Resident Evil 4 (2023)',
#       'japanese': None,
#       'twitch': 'Resident Evil 4'},
#      'boostReceived': 17,
#      'boostDistinctDonors': 8,
#      'abbreviation': 're4r',
#      'weblink': 'https://www.speedrun.com/re4r',
#      'discord': 'https://discord.gg/X82X7cbjeC',
#      'released': 2023,
#      'release-date': '2023-03-15',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime'],
#       'default-time': 'realtime',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['nzelkr6q',
#       'o7e2mx6w',
#       '8gej2n93',
#       '4p9zjrer',
#       'nzelyv9q',
#       'o7e2xj9w'],
#      'regions': ['pr184lqn',
#       'e6lxy1dz',
#       'o316x197',
#       'mol4z19n',
#       'p2g50lnk',
#       'ypl25l47'],
#      'genres': ['oy5gp5e3'],
#      'engines': ['r81p4m1d'],
#      'developers': ['myzo3pzq'],
#      'publishers': ['k564wnw1'],
#      'moderators': {'o8674wjz': 'super-moderator',
#       'pj05zm8w': 'super-moderator',
#       '48ge6kyj': 'super-moderator',
#       '68w6ld4j': 'super-moderator',
#       'e8erpl6j': 'super-moderator',
#       'v81l19rx': 'super-moderator',
#       '8qz7dy08': 'moderator',
#       'x35opl7j': 'super-moderator',
#       '8r7k6kqj': 'super-moderator',
#       'jmp1ldej': 'super-moderator',
#       '86nqdq5x': 'super-moderator',
#       '8g56kg2j': 'super-moderator',
#       'jm31r5z8': 'super-moderator',
#       'jnpnodq8': 'super-moderator'},
#      'created': '2023-02-20T19:29:33Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/images/logo.png'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/o1yjv5o1/cover?v=375c0c5'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/favicon?v=33842fb'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/1st?v=a57e2f0'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/2nd?v=1fd4c62'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/3rd?v=47b5c10'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/6wy9md58/background?v=0d0166b'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=o1yjv5o1'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/gnyj1xnx'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/o1yjv5o1/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/o1yjv5o1/category/jdz0l4r2'}]}},
#    'category': {'data': {'id': 'jdz0l4r2',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/re4r#Any',
#      'type': 'per-game',
#      'rules': "- Run must be started from a New Game file.\n- No NG+ items, unlocks or DLC items are allowed. This includes:\n  - Extra treasure map\n  - Charms\n  - Any accessories that have an ability/advantage including sunglasses.\n- All Out of Bounds, Auto Save Clips, Merchant Clips, or Sniper Clips are allowed, this includes Dufflebag skip. However, the altar dufflebag is still banned. DA0 is also banned.\n- FPS swapping during a run is banned except during the following areas\n  - Chapter 1 Village Siege\n  - Del Lago Fight\n  - Knight on the stairs at the end of chapter 9's Ashley section\n  - Carrying Ashley in chapter 15 (You may also pause buffer here)\n  - Setting up the dufflebag OOB (you may only swap between 30 and 120)",
# ...
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/7dgmm6pd'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/pj02g98w'}]},
#    'game': {'data': {'id': 'nd28wjrd',
#      'names': {'international': 'DEATHLOOP',
#       'japanese': None,
#       'twitch': 'DEATHLOOP'},
#      'boostReceived': 0,
#      'boostDistinctDonors': 0,
#      'abbreviation': 'deathloop',
#      'weblink': 'https://www.speedrun.com/deathloop',
#      'discord': 'https://discord.gg/dRNJ6YRPUY',
#      'released': 2021,
#      'release-date': '2021-09-14',
#      'ruleset': {'show-milliseconds': False,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gej2n93', '4p9zjrer', 'nzelyv9q', 'o7e2xj9w'],
#      'regions': [],
#      'genres': ['pm21pl24', '9rnvvrnq'],
#      'engines': ['k1nj2y3o'],
#      'developers': ['l4eprzro'],
#      'publishers': ['kd6jv6p0'],
#      'moderators': {'pj02g98w': 'super-moderator',
#       'kjpem4xq': 'moderator',
#       'qjnprp28': 'moderator',
#       'qjok9g78': 'moderator',
#       '8lppz64j': 'moderator'},
#      'created': '2021-08-31T21:01:34Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/2wokpmk8/logo?v=f3a242a'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/nd28wjrd/cover?v=6f4541c'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/nd28wjrd/cover?v=6f4541c'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/nd28wjrd/cover?v=6f4541c'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/nd28wjrd/cover?v=6f4541c'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/2wokpmk8/favicon?v=f15a6be'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/images/1st.png'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/images/2nd.png'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/images/3rd.png'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/2wokpmk8/background?v=a952e84'},
#       'foreground': {'uri': None}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=nd28wjrd'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/yr4gon12'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/nd28wjrd/category/7dgmm6pd'}]}},
#    'category': {'data': {'id': '7dgmm6pd',
#      'name': 'Any%',
#      'weblink': 'https://www.speedrun.com/deathloop#Any',
#      'type': 'per-game',
#      'rules': None,
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgmm6pd'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/nd28wjrd'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgmm6pd/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/7dgmm6pd/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=7dgmm6pd'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/nd28wjrd/category/7dgmm6pd'}]}}},
#   {'place': 4,
#    'run': {'id': 'y695726y',
#     'weblink': 'https://www.speedrun.com/re5steam/run/y695726y',
#     'game': '369po01l',
#     'level': None,
#     'category': '02qjgqyd',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=cpPJZyygbyc'},
#       {'uri': 'https://www.twitch.tv/videos/1116561507'}]},
#     'comment': 'SpiceeTV POV https://www.youtube.com/watch?v=cpPJZyygbyc',
#     'status': {'status': 'verified',
#      'examiner': '8qz7dy08',
#      'verify-date': '2021-08-13T19:38:44Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'},
#      {'rel': 'user',
#       'id': '7j44gevj',
#       'uri': 'https://www.speedrun.com/api/v1/users/7j44gevj'}],
#     'date': '2021-08-12',
#     'submitted': '2021-08-13T00:33:59Z',
#     'times': {'primary': 'PT1H28M32S',
#      'primary_t': 5312,
#      'realtime': 'PT1H28M32S',
#      'realtime_t': 5312,
#      'realtime_noloads': None,
#      'realtime_noloads_t': 0,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'ylq64p38': 'gq7w40y1',
#      'wlekwgel': '21gm5jo1',
#      '5lypkqjl': '5lm6dnm1',
#      'onv74q0n': 'klrmeemq',
#      'p855v1v8': '1gnw28nl',
#      '9l795pqn': '1w47nmoq'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/y695726y'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/369po01l'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/02qjgqyd'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/8qz7dy08'}]},
#    'game': {'data': {'id': '369po01l',
#      'names': {'international': 'Resident Evil 5 (Steam)',
#       'japanese': 'バイオハザード５',
#       'twitch': 'Resident Evil 5'},
#      'boostReceived': 4,
#      'boostDistinctDonors': 2,
#      'abbreviation': 're5steam',
#      'weblink': 'https://www.speedrun.com/re5steam',
#      'discord': 'https://discord.gg/dwDtkWq',
#      'released': 2009,
#      'release-date': '2009-09-15',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads', 'ingame'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gej2n93'],
#      'regions': [],
#      'genres': ['qdnqekn8', 'jp231xn6'],
#      'engines': [],
#      'developers': ['myzo3pzq'],
#      'publishers': ['k564wnw1'],
#      'moderators': {'pj0v0zwx': 'super-moderator',
#       '68w1po4x': 'moderator',
#       'v8lelm4x': 'moderator',
#       '8r76zdwj': 'moderator',
#       'x7mkvnvx': 'super-moderator'},
#      'created': None,
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/logo?v=b5b1b64'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/369po01l/cover?v=62aacd3'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/369po01l/cover?v=62aacd3'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/369po01l/cover?v=62aacd3'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/369po01l/cover?v=62aacd3'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/favicon?v=e67189e'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/1st?v=78bea7e'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/2nd?v=eb3a1aa'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/3rd?v=1fe8c03'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/background?v=058ed62'},
#       'foreground': {'uri': 'https://www.speedrun.com/static/theme/pr69dor9/foreground?v=0c3bf33'}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=369po01l'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/gnyj1xnx'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/369po01l/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/369po01l/category/n2yv572o'}]}},
#    'category': {'data': {'id': '02qjgqyd',
#      'name': 'New Game',
#      'weblink': 'https://www.speedrun.com/re5steam#New_Game',
#      'type': 'per-game',
#      'rules': '**Read the Game Rules as well**\r\n\r\n**New Game Rules**\r\n\r\n------------\r\n\r\nRuns must be done on a fresh save file (https://www.speedrun.com/re5steam/guide/m55l4) or no save file at all.\r\n\r\nAs of 26 February 2023, DLC costumes unlocked by default on a new file (Warrior/Business) are prohibited from use in speedruns.',
#      'players': {'type': 'up-to', 'value': 2},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/02qjgqyd'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/369po01l'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/02qjgqyd/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/02qjgqyd/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=02qjgqyd'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/369po01l/category/02qjgqyd'}]}}},
#   {'place': 96,
#    'run': {'id': 'mr190gdz',
#     'weblink': 'https://www.speedrun.com/re4steam/run/mr190gdz',
#     'game': 'j1nem5x1',
#     'level': None,
#     'category': '824r4wgd',
#     'videos': {'links': [{'uri': 'https://www.youtube.com/watch?v=he9ZHmRy8EQ'}]},
#     'comment': 'big huge\r\n\r\n[Mod note] .63 is 630 milliseconds, not 063. ',
#     'status': {'status': 'verified',
#      'examiner': '8dwlw3oj',
#      'verify-date': '2021-05-04T05:56:39Z'},
#     'players': [{'rel': 'user',
#       'id': '8d32vrgx',
#       'uri': 'https://www.speedrun.com/api/v1/users/8d32vrgx'}],
#     'date': '2021-05-04',
#     'submitted': '2021-05-04T05:09:30Z',
#     'times': {'primary': 'PT1H35M34.630S',
#      'primary_t': 5734.63,
#      'realtime': 'PT1H40M2S',
#      'realtime_t': 6002,
#      'realtime_noloads': 'PT1H35M34.630S',
#      'realtime_noloads_t': 5734.63,
#      'ingame': None,
#      'ingame_t': 0},
#     'system': {'platform': '8gej2n93', 'emulated': False, 'region': None},
#     'splits': None,
#     'values': {'789k21ql': 'rqvdw6wq',
#      '6njkq96l': '4qy0ezdl',
#      'wle629e8': 'klr7wj2q'},
#     'links': [{'rel': 'self',
#       'uri': 'https://www.speedrun.com/api/v1/runs/mr190gdz'},
#      {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1'},
#      {'rel': 'category',
#       'uri': 'https://www.speedrun.com/api/v1/categories/824r4wgd'},
#      {'rel': 'platform',
#       'uri': 'https://www.speedrun.com/api/v1/platforms/8gej2n93'},
#      {'rel': 'examiner',
#       'uri': 'https://www.speedrun.com/api/v1/users/8dwlw3oj'}]},
#    'game': {'data': {'id': 'j1nem5x1',
#      'names': {'international': 'Resident Evil 4 (Steam)',
#       'japanese': None,
#       'twitch': 'Resident Evil 4'},
#      'boostReceived': 1,
#      'boostDistinctDonors': 1,
#      'abbreviation': 're4steam',
#      'weblink': 'https://www.speedrun.com/re4steam',
#      'discord': 'https://discord.gg/jxFTc8kzQb',
#      'released': 2014,
#      'release-date': '2014-02-27',
#      'ruleset': {'show-milliseconds': True,
#       'require-verification': True,
#       'require-video': True,
#       'run-times': ['realtime', 'realtime_noloads'],
#       'default-time': 'realtime_noloads',
#       'emulators-allowed': False},
#      'romhack': False,
#      'gametypes': [],
#      'platforms': ['8gej2n93'],
#      'regions': [],
#      'genres': ['94n4pn0w', 'oy5gp5e3'],
#      'engines': [],
#      'developers': ['myzo3pzq'],
#      'publishers': ['k564wnw1'],
#      'moderators': {'qjopz90x': 'super-moderator',
#       '68w95oqj': 'moderator',
#       '8dwlw3oj': 'super-moderator',
#       '8v525m2j': 'moderator',
#       'joo1w20j': 'super-moderator'},
#      'created': '2018-10-22T02:18:32Z',
#      'assets': {'logo': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/logo?v=f5fde10'},
#       'cover-tiny': {'uri': 'https://www.speedrun.com/static/game/j1nem5x1/cover?v=e360951'},
#       'cover-small': {'uri': 'https://www.speedrun.com/static/game/j1nem5x1/cover?v=e360951'},
#       'cover-medium': {'uri': 'https://www.speedrun.com/static/game/j1nem5x1/cover?v=e360951'},
#       'cover-large': {'uri': 'https://www.speedrun.com/static/game/j1nem5x1/cover?v=e360951'},
#       'icon': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/favicon?v=7ed6298'},
#       'trophy-1st': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/1st?v=67ff7a4'},
#       'trophy-2nd': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/2nd?v=9c9d4e7'},
#       'trophy-3rd': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/3rd?v=0981c60'},
#       'trophy-4th': {'uri': None},
#       'background': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/background?v=9cf7ed2'},
#       'foreground': {'uri': 'https://www.speedrun.com/static/theme/9wp0nn83/foreground?v=0c3bf33'}},
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?game=j1nem5x1'},
#       {'rel': 'levels',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1/levels'},
#       {'rel': 'categories',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1/categories'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1/records'},
#       {'rel': 'series',
#        'uri': 'https://www.speedrun.com/api/v1/series/gnyj1xnx'},
#       {'rel': 'derived-games',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1/derived-games'},
#       {'rel': 'romhacks',
#        'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1/derived-games'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1nem5x1/category/824r4wgd'}]}},
#    'category': {'data': {'id': '824r4wgd',
#      'name': 'New Game',
#      'weblink': 'https://www.speedrun.com/re4steam#New_Game',
#      'type': 'per-game',
#      'rules': '',
#      'players': {'type': 'exactly', 'value': 1},
#      'miscellaneous': False,
#      'links': [{'rel': 'self',
#        'uri': 'https://www.speedrun.com/api/v1/categories/824r4wgd'},
#       {'rel': 'game', 'uri': 'https://www.speedrun.com/api/v1/games/j1nem5x1'},
#       {'rel': 'variables',
#        'uri': 'https://www.speedrun.com/api/v1/categories/824r4wgd/variables'},
#       {'rel': 'records',
#        'uri': 'https://www.speedrun.com/api/v1/categories/824r4wgd/records'},
#       {'rel': 'runs',
#        'uri': 'https://www.speedrun.com/api/v1/runs?category=824r4wgd'},
#       {'rel': 'leaderboard',
#        'uri': 'https://www.speedrun.com/api/v1/leaderboards/j1nem5x1/category/824r4wgd'}]}}}]}

# %%
entries = []
for runner in runners_list:
    response = get_response(runner)
    
    for ind in list(range(0,len(response.json()['data']))):
        entry = pd.DataFrame({
            'runner' : [runner],
            'place' : [response.json()['data'][ind]['place']],
            'game' : [response.json()['data'][ind]['game']['data']['names']['twitch']],
            'category' : [response.json()['data'][ind]['category']['data']['name']],
            'time' : [response.json()['data'][ind]['run']['times']['primary_t']],
            'date' : [response.json()['data'][ind]['run']['date']]
        })
        entries.append(entry)
runs_df = pd.concat(entries)
runs_df
# Out:
#             runner  place                      game              category  \
# 0   CaptainEzekiel      1  Alone in the Dark (2024)                  Any%
# 0   CaptainEzekiel      1  Alone in the Dark (2024)                  Any%
# 0   CaptainEzekiel      1  Alone in the Dark (2024)                  Any%
# 0   CaptainEzekiel      2  Alone in the Dark (2024)                  Any%
# 0   CaptainEzekiel      2  Alone in the Dark (2024)                  Any%
# ..             ...    ...                       ...                   ...
# 0             Zic3      4                    Owlboy       Any% Corruption
# 0             Zic3     13          Enviro-Bear 2000               5 Years
# 0             Zic3      5               Titan Souls  Any% (Beat the Game)
# 0             Zic3     11               Titan Souls  Any% (Beat the Game)
# 0             Zic3      7               Titan Souls  Any% (Beat the Game)
#
#        time        date
# 0   1531.93  2024-04-11
# 0   1557.43  2024-04-08
# 0   1597.73  2024-04-06
# 0   3114.00  2024-03-31
# 0   3135.00  2024-03-31
# ..      ...         ...
# 0   2599.00  2017-02-05
# 0    530.00  2017-02-04
# 0    707.86  2017-01-25
# 0    832.72  2016-12-26
# 0   1457.00  2016-11-15
#
# [234 rows x 6 columns]

# %%
runs_df.runner.value_counts()
# Out:
# runner
# Zic3              80
# gymnast86         72
# CaptainEzekiel    41
# spicee            34
# maeeeeee           7
# Name: count, dtype: int64

# %%
runs_df.loc[runs_df.runner == 'maeeeeee']
# Out:
#      runner  place             game         category     time        date
# 0  maeeeeee      1  Baldur's Gate 3  Any% (All Acts)  1137.50  2024-02-23
# 0  maeeeeee      1  Baldur's Gate 3  Any% (All Acts)  1110.13  2024-02-15
# 0  maeeeeee      1  Baldur's Gate 3  Any% (All Acts)  1172.38  2024-02-13
# 0  maeeeeee      2  Baldur's Gate 3             Sex%   257.00  2024-01-30
# 0  maeeeeee      1  Baldur's Gate 3             Sex%   118.68  2023-10-20
# 0  maeeeeee      5        Starfield         New Game  2404.00  2023-09-29
# 0  maeeeeee      1  Baldur's Gate 3             Any%   211.25  2023-09-18

# %%
runs_df.loc[runs_df.runner == 'CaptainEzekiel']
# Out:
#            runner  place                                            game  \
# 0  CaptainEzekiel      1                        Alone in the Dark (2024)
# 0  CaptainEzekiel      1                        Alone in the Dark (2024)
# 0  CaptainEzekiel      1                        Alone in the Dark (2024)
# 0  CaptainEzekiel      2                        Alone in the Dark (2024)
# 0  CaptainEzekiel      2                        Alone in the Dark (2024)
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel     10                                 Resident Evil 4
# 0  CaptainEzekiel      2                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      9                                 Resident Evil 4
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1  Resident Evil 7: Biohazard Category Extensions
# 0  CaptainEzekiel      1  Resident Evil 7: Biohazard Category Extensions
# 0  CaptainEzekiel      2                       Resident Evil 7 biohazard
# 0  CaptainEzekiel    145                                     Amok Runner
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1  Resident Evil 7: Biohazard Category Extensions
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1  Resident Evil 7: Biohazard Category Extensions
# 0  CaptainEzekiel      3                           Resident Evil Village
# 0  CaptainEzekiel      2                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      2                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      8                                      Elden Ring
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1  Resident Evil 7: Biohazard Category Extensions
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel     42                                 Resident Evil 2
# 0  CaptainEzekiel     50
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1                       Resident Evil 7 biohazard
# 0  CaptainEzekiel      1  Resident Evil 7: Biohazard Category Extensions
# 0  CaptainEzekiel      6                      Resident Evil: Revelations
# 0  CaptainEzekiel     27                                       Diablo II
#
#              category      time        date
# 0                Any%  1531.930  2024-04-11
# 0                Any%  1557.430  2024-04-08
# 0                Any%  1597.730  2024-04-06
# 0                Any%  3114.000  2024-03-31
# 0                Any%  3135.000  2024-03-31
# 0                Any%  4082.000  2024-03-14
# 0          Knife Only  5827.000  2024-03-08
# 0       Separate Ways  2764.000  2023-11-19
# 0          Knife Only  6054.000  2023-10-16
# 0          Knife Only  5740.000  2023-08-06
# 0                Any%  6870.000  2023-05-12
# 0                Any%  4194.000  2023-01-14
# 0      No Guest House  3384.000  2023-01-14
# 0      No Guest House  3258.000  2023-01-11
# 0                Any%  4091.000  2023-01-11
# 0                Any%  1816.007  2022-12-28
# 0          Knife Only  6859.000  2022-11-06
# 0                100%  5698.000  2022-09-25
# 0                100%  5885.000  2022-09-22
# 0                Any%  5277.000  2022-08-19
# 0      No Guest House  4031.000  2022-08-18
# 0                Any%  5487.000  2022-08-12
# 0      No Guest House  4256.000  2022-07-28
# 0          Glitchless  5370.000  2022-06-18
# 0                Any%  1314.000  2022-04-15
# 0                Any%  1402.000  2022-04-15
# 0                Any%  1458.000  2022-04-15
# 0                Any%  1333.000  2022-04-15
# 0  Any% No Wrong Warp  3580.000  2022-04-07
# 0                100%  5732.000  2022-02-22
# 0                100%  5600.000  2022-01-30
# 0      No Guest House  3987.000  2022-01-25
# 0                Any%  5338.000  2022-01-23
# 0                Any%  5204.000  2022-01-22
# 0       New Game (PC)  3011.000  2022-01-01
# 0                Any%  3548.000  2021-12-18
# 0           Daughters   436.160  2021-11-15
# 0             Bedroom   348.070  2021-11-13
# 0      No Guest House  4117.000  2021-07-01
# 0            New Game  6267.000  2021-04-04
# 0           Any% Baal  6079.000  2020-04-19

# %%
runs_df.dtypes
# Out:
# runner       object
# place         int64
# game         object
# category     object
# time        float64
# date         object
# dtype: object

# %%
runs_df.date = pd.to_datetime(runs_df.date)

# %%
runs_df.date.max()
# Out:
# Timestamp('2024-04-11 00:00:00')

# %%
runs_df.loc[runs_df.date == runs_df.date.max()]
# Out:
#            runner  place                      game category     time  \
# 0  CaptainEzekiel      1  Alone in the Dark (2024)     Any%  1531.93
#
#         date
# 0 2024-04-11

# %%
runs_df.loc[runs_df.date == runs_df.date.min()]
# Out:
#       runner  place                                 game     category    time  \
# 0  gymnast86     13  The Legend of Zelda: The Wind Waker  Din's Pearl  3110.0
#
#         date
# 0 2013-09-16

# %%
runs_df.loc[runs_df.place < 4]['runner'].value_counts()
# Out:
# runner
# CaptainEzekiel    33
# gymnast86         31
# Zic3              19
# spicee            18
# maeeeeee           6
# Name: count, dtype: int64

# %%
runs_df.loc[runs_df.place < 4].loc[runs_df['date'].dt.year == 2022]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 runs_df.loc[runs_df.place < 4].loc[runs_df['date'].dt.year == 2022]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1325, in _LocIndexer._getitem_axis(self, key, axis)
#    1323     return self._get_slice_axis(key, axis=axis)
#    1324 elif com.is_bool_indexer(key):
# -> 1325     return self._getbool_axis(key, axis=axis)
#    1326 elif is_list_like_indexer(key):
#    1327     # an iterable multi-selection
#    1328     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1123, in _LocationIndexer._getbool_axis(self, key, axis)
#    1121 key = check_bool_indexer(labels, key)
#    1122 inds = key.nonzero()[0]
# -> 1123 return self.obj._take_with_is_copy(inds, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3948, in NDFrame._take_with_is_copy(self, indices, axis)
#    3940 def _take_with_is_copy(self: NDFrameT, indices, axis: Axis = 0) -> NDFrameT:
#    3941     """
#    3942     Internal version of the `take` method that sets the `_is_copy`
#    3943     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3946     See the docstring of `take` for full explanation of the parameters.
#    3947     """
# -> 3948     result = self._take(indices=indices, axis=axis)
#    3949     # Maybe set copy if we didn't actually change the index.
#    3950     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3924     if (
#    3925         axis == 0
#    3926         and indices.ndim == 1
#    3927         and using_copy_on_write()
#    3928         and is_range_indexer(indices, len(self))
#    3929     ):
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
#    3933     indices,
#    3934     axis=self._get_block_manager_axis(axis),
#    3935     verify=True,
#    3936     convert_indices=convert_indices,
#    3937 )
#    3938 return self._constructor(new_data).__finalize__(self, method="take")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:960, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     958 n = self.shape[axis]
#     959 if convert_indices:
# --> 960     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     962 new_labels = self.axes[axis].take(indexer)
#     963 return self.reindex_indexer(
#     964     new_axis=new_labels,
#     965     indexer=indexer,
#    (...)
#     968     copy=None,
#     969 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:284, in maybe_convert_indices(indices, n, verify)
#     282     mask = (indices >= n) | (indices < 0)
#     283     if mask.any():
# --> 284         raise IndexError("indices are out-of-bounds")
#     285 return indices
#
# IndexError: indices are out-of-bounds

# %%
runs_df.loc[runs_df.place == 1]['runner'].value_counts()
# Out:
# runner
# CaptainEzekiel    26
# gymnast86         14
# spicee             7
# maeeeeee           5
# Zic3               4
# Name: count, dtype: int64

# %%
runs_df.loc[runs_df.place < 4]['runner'].value_counts()
# Out:
# runner
# CaptainEzekiel    33
# gymnast86         31
# Zic3              19
# spicee            18
# maeeeeee           6
# Name: count, dtype: int64

# %%
runs_df.loc[runs_df['date'].dt.year == 2023]['runner'].value_counts()
# Out:
# runner
# spicee            14
# Zic3              14
# CaptainEzekiel     8
# gymnast86          6
# maeeeeee           3
# Name: count, dtype: int64

# %%
runs_df.loc[runs_df['date'].dt.year == 2023].groupby(by = 'runner')['game'].nunique()
# Out:
# runner
# CaptainEzekiel    3
# Zic3              5
# gymnast86         5
# maeeeeee          2
# spicee            9
# Name: game, dtype: int64

# %%
runs_df.to_csv('data/runner_pb.csv',index=False)

# %%
pd.read_csv('data/runner_pb.csv')
# Out:
#              runner  place                      game              category  \
# 0    CaptainEzekiel      1  Alone in the Dark (2024)                  Any%
# 1    CaptainEzekiel      1  Alone in the Dark (2024)                  Any%
# 2    CaptainEzekiel      1  Alone in the Dark (2024)                  Any%
# 3    CaptainEzekiel      2  Alone in the Dark (2024)                  Any%
# 4    CaptainEzekiel      2  Alone in the Dark (2024)                  Any%
# ..              ...    ...                       ...                   ...
# 229            Zic3      4                    Owlboy       Any% Corruption
# 230            Zic3     13          Enviro-Bear 2000               5 Years
# 231            Zic3      5               Titan Souls  Any% (Beat the Game)
# 232            Zic3     11               Titan Souls  Any% (Beat the Game)
# 233            Zic3      7               Titan Souls  Any% (Beat the Game)
#
#         time        date
# 0    1531.93  2024-04-11
# 1    1557.43  2024-04-08
# 2    1597.73  2024-04-06
# 3    3114.00  2024-03-31
# 4    3135.00  2024-03-31
# ..       ...         ...
# 229  2599.00  2017-02-05
# 230   530.00  2017-02-04
# 231   707.86  2017-01-25
# 232   832.72  2016-12-26
# 233  1457.00  2016-11-15
#
# [234 rows x 6 columns]
